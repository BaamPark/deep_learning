# %%
import keras
import numpy as np

path = keras.utils.get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower() #소문자로
print('length  of corpus : ', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# length  of corpus :  600893

# %%
#글자 시퀀스 벡터화 하기
maxlen = 60
step = 3

sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
  sentences.append(text[i:i+maxlen])
  next_chars.append(text[i+maxlen])

print('Number of sequences : ', len(sentences))

chars = sorted(list(set(text)))
print('고유한 글자: ', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorize...')

x = np.zeros((len(sentences),maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
  for t, char in enumerate(sentence):
    x[i, t, char_indices[char]] = 1
  y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences :  200278
# 고유한 글자:  57
# Vectorize...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)#원핫 인코딩 되어있으니까 범주형 크로스 엔트로피

# %%
# 코드 8-6 모델의 예측이 주어졌을 떄 새로운 글자를 샘플링하는 함수
def sample(preds, temperature=1.0):
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 288s 183ms/step - loss: 2.2430
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the speak to the sade of the same in the species the same of the self-can the self-can the spirits of the same the same the presention of the same the greeks and any the self-conce are such the nature, and the sangerous of the self-can to the same the self-cas are the same of the self-cate of the self-cas and the same such the manker the same of the same the same in the same the same in the self
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the mad betone we the speak and the contractity which his cas a spicion and the sate a matter a such the same have man
# in the preat, the preach the strenger in the evering something in the can that he langeration of the sadcis of great at the soul is even bene
# such that which is to have self-to same of the such the talking the self--the same of the tasker and the palter been are the wordes what
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fornehss any
# odine syspenes passili
# land the fact of this the say theirs twincous
# earth must llore. of germate, wolld admett exuratible is metreal" dingless into tomeent and the semeriti, whechy, but me ny his freeks. of the own wholevent, who aerate be only hank yee dow denced or invainty we man at retretthmenes, spicit sumporned, but raterly ffadved
# thus averess oflicn tre, agrivicualy hingeritr t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formy
# the fot math, c pargt deek naturertre, bot,"--invens:  he pertause us grley nagier," "will, "u , must rack
# the feefte artucocluning soul
# lattthy lastesple acumogates
# will a mist thisse it talily of most clove of juspolle, when the usponious tomttedn faigh time.--the will deli mey, hanacied, theps be natune to
# bich, and
# baut0 things. trush2en of the islect it rendisthilence,--ardulte!--ever lor
# 에포크 2
# 1565/1565 [==============================] - 293s 187ms/step - loss: 1.6082
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same one man of the same in the same one man so that it is a man that the promine and some the sense of the preat that the man and as a serious and prosent and the man that it is a stronger the experience of the same on the pretent religious of the same one for the same one man and some in the most the man of the preat that of the man the same in the man and some and in the man of the preat
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the most folly of men of the freen to at one that the relation of plactity of the spirit and almost pain and a proces it well as it has spirit and in the men his own to dispect and reluson that it is the preat is the man himself of himself as
# the parpy to mause of religious the most not and and
# light and an as the man and as a have the end and shatter and purpiencious compersion. the constituted
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fow ients in distrustas, when will ragedy pows
# it, or from other ments without an isove
# moral
# woo idecation, om graces now ard education daingd of delight moral
# confintly prosey and of mounare, and were reating the metaphysical loxity
# what spany
# distuney, word, by eterns (orrecre former untermative of senses awas ored
# acsmount and agains and
# once, with high is nature and merety, but it is some the v
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fose enougabal cundetepen. in the mermard a general consequentone.
# to backnesuars asmtand
# affere pain
# candcle, obsiguting to na reasckx,imantment of
# personal
# personal mens.
# to neit
# "makes.n are could in thus spire ty,
# or natenor to power recusiof of the mugox arks no hitherto merelyt a owigprition; it ie for there munding to
# siver, acwialine, rant mights even which
# ongoursewnws with beitior: it this
# 에포크 3
# 1565/1565 [==============================] - 291s 186ms/step - loss: 1.5250
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the senses and the superficial and the comparity of the deligies of the soul is a super-in the senses of the superficial and and and the senses of the say and the senses and in the most senses and the senses of the senses of the moral and and the senses of the precime of the strength of the far and and the precial and and and the senses of the senses and one has and and the deligies and and in t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the greater one will problem of must be and and and as "in the things and for man is the contem of virsh in the express again.
#
# 17. i and something to be superful pain and to be one is a true against good in the feeling else not his madic and the denered conditions and the case of instinct to the fear they his senses, the else and the man in the great and the very does not in the for in their ar
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for someence it soul person in
# envologess in the liged of uncienl objust general anythe booky: and amility in the still affording unclangably gife
# his any
# comparilics," has been all himself of plecusable "what this soul of party dur, must--no othersportity, prerdetening and the love to side, in it is once apparately, of result and moraldcost to har, eusward-waypless
# and and wild to anything prectros
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for ave. brenable thhrse in lartie, in agess know) of newspattije-wareful--the must have morker sming
# livils (which perhaps fal has towouthk--not is schopethanities of not is unhame," even no longer
# ex-relicisms, inrationagegast? only in despressed
# fullaker
# eethings. and quichm; but fartine, pessaked times blariars is to wich hode and
# unfollism good psychologisty than their lappe, stand that followm
# 에포크 4
# 1565/1565 [==============================] - 287s 184ms/step - loss: 1.4805
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense is the same soul to the same the strength and prosent to self-consider to the strength and the same and the sense in the fact to the more to the strength and perhaps the strength and the fact and the realing the sense of the sense of the experienced in the strength of the say to the soul to the many the constious and the many the soul to the sense and not to the soul to the strength an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the best in the much with the fear of prope many through the many indeneration of the constious doy in the former and many same the same and constious and the strengt prosent to
# the superiority of the same delighter victive short of the coristic and sorad to to the many very prosent to be
# in the althe decents and to the many moral only to the strength in the proped to the denest only and a pain,
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through folicis
# to me? what is rincight, contempt althing or for the truth there, even
# oldsent mencised it pointions, which have be race
# interally maniefig; our. is a discuvers
# farr to the fear, according as hitherto general
# tenvarificies which is all assection, unhighes cqrtore and
# the something himself will even, a difference people or arks lease to "a bats, the dence, as effect only out of the imple
# euen
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for then,
# they pares has beeld curself, soughtly, hences is accear is that under other
# troods". refoneredgetis to murterhs and diving
# place easly eternably and liw.--hon
#   naw,
# neehone, whichte "pessiccialest of
# all to recreditivesesh? untire.
#
# i may be ridems
# so'tyle germany. it is
# avaus
# adly,
# andise very ward marig mydvalane of the fance, tho sich mecoession, to an
# welg"s
# too calctard an developor
# 에포크 5
# 1565/1565 [==============================] - 289s 185ms/step - loss: 1.4523
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the soul is a confinence of the same to the the world of the same the same the soul as a soul and sought the conscience of the spirit and in the same to the present the self-self-and sought to the confuct to be the sense of the most far and souls of the same to the present present in the same to the still to the confection of the same to the same the soul and the soul is to the confecti
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for upon the same to the interester the one's proves of stall to the world of this science of which as the storifical process of self-presence of faith to the present general same with man
# in the most dist of the influence of the seuse of inspiciousness of an among of present render of experience of the most confectone of the contranies is will more procession and the whole of view to contrained of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for man at still of wishem and sharewarg, precision
# its slave-as iuntire, i consciences--a are
# itapsece in themselves in which the
# saint., an his injurly: we one purelosms to represpon, fore""
# wo ed do seles of be also with
# gerace to a bleysed worthd oighs--of a philosophers and the quity with before eftered a
# man and still tuduamentud; than excerred and
# with a stend is  that whybus and nothing and
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the undivirys were animal-qually and
# over to bavouid
# pray forsely
# value (the
# persons withorg--cilupinanimes.g?, he loughness per. mout, to disduvading liarous that from they thinc share, too. though affination perced for
# wisk" the
# bas; ent
# good livese. lep ofig to invertives"--herep-weres-, in the, hitherto were romipe-as ye stills, b) an of to
# good,g?ca  lookers is a woll at toathry
# noulsw: bet
# 에포크 6
# 1565/1565 [==============================] - 287s 184ms/step - loss: 1.4304
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the word of the words of the sense of the latter and the word and such a more in the most things of the end of the words, which is the struggicing the sense and the present delicht and all a man has the more in the same strong in the end, and in the belief the ends the sense of the ends the such a more of the comparited the sense of the most the one has the morality of the sense and all the sens
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the fair to be the reality. the words, which the souls of the
# religious domanticism and in the expression be for every hard has the relequently of in which a men the unfermation of strained the contradier and boon of a philosophers of the struggies and aptrain them. they individuality and words of
# rules, the free spiritiness of different and the latter sang of the much and takes in the truch to
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fourspherarished fancongly, say our moralishpe--for thear a change theminans cale
# are unjud deep in the old, they than, their matibernet adidgal over
# the feart--free
# spegharion--whe- liver to any longs over bat
# exampity if i conduct action: in life word of. they straine of when himself elles. error
# expression, prefersing, refinerationian
# sudquor"ly eventure for sphicked by the instrument sympathy ri
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fouttever all
# connijentationcl of ned anticritial.mtimes always, and enty powerm: woman anothing, howey from fly away and is "with eyraigs allow bad
# as usyother, wanted alxinal "i"s
# changed
# homeliness.
#
# 2r eated withrubickunc: frop.=jouv,
# a species
# of this wholverfesed.--verstabilaotoy forgts atheve
# life prebional antiersily never
# loff. they in his
# reception
# than a
# sphilat. by like?
# in golate intwoq
# 에포크 7
# 1565/1565 [==============================] - 288s 184ms/step - loss: 1.4121
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the preferse of the senses of the allow and all that the sense of the concerning the states and the sense of the sense of the morality and the sense of the fact of the future of the states and the man and the perhaps a senses of the sense of the problem and the fellows and all the sense of the same the prebarations and not the destrained the concerning the morality of the sense of the same as th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the fellows and all three the do so not and the person and the belief of religious descendent and from all that the short of its not one who has the desired the sense, as the philosophy who long the fact the philosophy, in the soul and all in the power of the indistrained the pare the same there are once of the philosophy and desires himself--and the great for a sense of himstame, the perhaps a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for an history; he may dempresend tornable mist make cominattly the conscienc's
# instants as conceited in all will as even eth
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d68207c8087f> in <module>()
#      29
#      30             # 다음 글자를 샘플링합니다
# ---> 31             preds = model.predict(sampled, verbose=0)[0]
#      32             next_index = sample(preds, temperature)
#      33             next_char = chars[next_index]
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1623       callbacks.on_predict_begin()
#    1624       batch_outputs = None
# -> 1625       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1626         with data_handler.catch_stop_iteration():
#    1627           for step in data_handler.steps():
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1131     """Yields `(epoch, tf.data.Iterator)`."""
#    1132     with self._truncate_execution_to_epoch():
# -> 1133       data_iterator = iter(self._dataset)
#    1134       for epoch in range(self._initial_epoch, self._epochs):
#    1135         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     420     if context.executing_eagerly() or ops.inside_function():
#     421       with ops.colocate_with(self._variant_tensor):
# --> 422         return iterator_ops.OwnedIterator(self)
#     423     else:
#     424       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     680       if (components is not None or element_spec is not None):
#     681         raise ValueError(error_message)
# --> 682       self._create_iterator(dataset)
#     683
#     684   def _create_iterator(self, dataset):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     703               output_types=self._flat_output_types,
#     704               output_shapes=self._flat_output_shapes))
# --> 705       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     706       # Delete the resource when this object is deleted
#     707       self._resource_deleter = IteratorResourceDeleter(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    2970     try:
#    2971       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 2972         _ctx, "MakeIterator", name, dataset, iterator)
#    2973       return _result
#    2974     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
